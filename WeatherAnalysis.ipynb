# %%
#apikey 5whYWDLZgjNaVNVcST3mVX:3uxZMtkeaq12fu5uvT1GyS

# %%
import http.client

conn = http.client.HTTPSConnection("api.collectapi.com")

headers = {
    'content-type': "application/json",
    'authorization': "apikey 5whYWDLZgjNaVNVcST3mVX:3uxZMtkeaq12fu5uvT1GyS"
    }

conn.request("GET", "/weather/getWeather?data.lang=tr&data.city=ankara", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"success":true,"city":"ankara","result":[{"date":"25.09.2024","day":"Çarşamba","icon":"https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbzWz8A.png?size=512x512","description":"açık","status":"Clear","degree":"22.81","min":"14.4","max":"24.26","night":"20.59","humidity":"33"},{"date":"26.09.2024","day":"Perşembe","icon":"https://cdnydm.com/permedia/4-txymOx-J8znrVLBm3yCg.png?size=512x512","description":"az bulutlu","status":"Clouds","degree":"24.21","min":"16.07","max":"25.66","night":"19.78","humidity":"29"},{"date":"27.09.2024","day":"Cuma","icon":"https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbzWz8A.png?size=512x512","description":"açık","status":"Clear","degree":"25.19","min":"15.97","max":"27.24","night":"21.02","humidity":"27"},{"date":"28.09.2024","day":"Cumartesi","icon":"https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbzWz8A.png?size=512x512","description":"açık","status":"Clear","degree":"26.39","min":"17.45","max":"28.79","night":"23.11","humidity":"25"},{"date":"29.09.2024","day":"P
# ...

# %%
import json

decode_data = data.decode("utf-8")
json_data = json.loads(decode_data)
print(json_data)
# Out:
# {'success': True, 'city': 'ankara', 'result': [{'date': '25.09.2024', 'day': 'Çarşamba', 'icon': 'https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbzWz8A.png?size=512x512', 'description': 'açık', 'status': 'Clear', 'degree': '22.81', 'min': '14.4', 'max': '24.26', 'night': '20.59', 'humidity': '33'}, {'date': '26.09.2024', 'day': 'Perşembe', 'icon': 'https://cdnydm.com/permedia/4-txymOx-J8znrVLBm3yCg.png?size=512x512', 'description': 'az bulutlu', 'status': 'Clouds', 'degree': '24.21', 'min': '16.07', 'max': '25.66', 'night': '19.78', 'humidity': '29'}, {'date': '27.09.2024', 'day': 'Cuma', 'icon': 'https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbzWz8A.png?size=512x512', 'description': 'açık', 'status': 'Clear', 'degree': '25.19', 'min': '15.97', 'max': '27.24', 'night': '21.02', 'humidity': '27'}, {'date': '28.09.2024', 'day': 'Cumartesi', 'icon': 'https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbzWz8A.png?size=512x512', 'description': 'açık', 'status': 'Clear', 'degree': '26.39', 'min': '17.45
# ...

# %%
import pandas as pd

weather_data = json_data["result"]
df = pd.DataFrame(weather_data)
df
# Out:
#          date        day                                               icon  \
# 0  25.09.2024   Çarşamba  https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbz...
# 1  26.09.2024   Perşembe  https://cdnydm.com/permedia/4-txymOx-J8znrVLBm...
# 2  27.09.2024       Cuma  https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbz...
# 3  28.09.2024  Cumartesi  https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbz...
# 4  29.09.2024      Pazar  https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbz...
# 5  30.09.2024  Pazartesi  https://cdnydm.com/permedia/zvWjzjmkp5WUUEWob4...
# 6  01.10.2024       Salı  https://cdnydm.com/permedia/zvWjzjmkp5WUUEWob4...
#
#     description  status degree    min    max  night humidity
# 0          açık   Clear  22.81   14.4  24.26  20.59       33
# 1    az bulutlu  Clouds  24.21  16.07  25.66  19.78       29
# 2          açık   Clear  25.19  15.97  27.24  21.02       27
# 3          açık   Clear  26.39  17.45  28.79  23.11       25
# ...

# %%
df.shape
# Out:
# (7, 10)

# %%
df.head(7)
# Out:
#          date        day                                               icon  \
# 0  25.09.2024   Çarşamba  https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbz...
# 1  26.09.2024   Perşembe  https://cdnydm.com/permedia/4-txymOx-J8znrVLBm...
# 2  27.09.2024       Cuma  https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbz...
# 3  28.09.2024  Cumartesi  https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbz...
# 4  29.09.2024      Pazar  https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbz...
# 5  30.09.2024  Pazartesi  https://cdnydm.com/permedia/zvWjzjmkp5WUUEWob4...
# 6  01.10.2024       Salı  https://cdnydm.com/permedia/zvWjzjmkp5WUUEWob4...
#
#     description  status degree    min    max  night humidity
# 0          açık   Clear  22.81   14.4  24.26  20.59       33
# 1    az bulutlu  Clouds  24.21  16.07  25.66  19.78       29
# 2          açık   Clear  25.19  15.97  27.24  21.02       27
# 3          açık   Clear  26.39  17.45  28.79  23.11       25
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         7 non-null      object
#  1   day          7 non-null      object
#  2   icon         7 non-null      object
#  3   description  7 non-null      object
#  4   status       7 non-null      object
#  5   degree       7 non-null      object
#  6   min          7 non-null      object
#  7   max          7 non-null      object
#  8   night        7 non-null      object
#  9   humidity     7 non-null      object
# dtypes: object(10)
# memory usage: 688.0+ bytes

# %%
df['date']=pd.to_datetime(df['date'])
# Out:
# <ipython-input-10-c85e97b4fa21>:1: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['date']=pd.to_datetime(df['date'])

# %%
df
# Out:
#         date        day                                               icon  \
# 0 2024-09-25   Çarşamba  https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbz...
# 1 2024-09-26   Perşembe  https://cdnydm.com/permedia/4-txymOx-J8znrVLBm...
# 2 2024-09-27       Cuma  https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbz...
# 3 2024-09-28  Cumartesi  https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbz...
# 4 2024-09-29      Pazar  https://cdnydm.com/permedia/LC1i84c3Z2MtLUDNbz...
# 5 2024-09-30  Pazartesi  https://cdnydm.com/permedia/zvWjzjmkp5WUUEWob4...
# 6 2024-10-01       Salı  https://cdnydm.com/permedia/zvWjzjmkp5WUUEWob4...
#
#     description  status degree    min    max  night humidity
# 0          açık   Clear  22.81   14.4  24.26  20.59       33
# 1    az bulutlu  Clouds  24.21  16.07  25.66  19.78       29
# 2          açık   Clear  25.19  15.97  27.24  21.02       27
# 3          açık   Clear  26.39  17.45  28.79  23.11       25
# 4          açık   Clear  27.02  18.03  29.32  23.29       23
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         7 non-null      datetime64[ns]
#  1   day          7 non-null      object
#  2   icon         7 non-null      object
#  3   description  7 non-null      object
#  4   status       7 non-null      object
#  5   degree       7 non-null      object
#  6   min          7 non-null      object
#  7   max          7 non-null      object
#  8   night        7 non-null      object
#  9   humidity     7 non-null      object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 688.0+ bytes

# %%
import seaborn as sns

# %%
sns.boxplot(y="degree", data=df)
# Out:
# <Axes: ylabel='degree'>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.lineplot(x="date", y="degree", data=df)
plt.title("Daily Temperature")
plt.xlabel("Date")
plt.ylabel("Temperature")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x="date", y="humidity", data=df)
plt.title("Daily Humidity")
plt.xlabel("Date")
plt.ylabel("Humidity")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="status", y="humidity", data=df)
plt.title("Status Vs humidity")
plt.xlabel("Status")
plt.ylabel("Humidity")
plt.show()

# %%
fig = px.pie(df, values='humidity', names='status', title='Status Vs humidity')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
